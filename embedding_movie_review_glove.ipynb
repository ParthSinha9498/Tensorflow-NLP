# %%
import string
from os import listdir
import re
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense,Flatten, Embedding
from keras.layers import Conv1D, MaxPool1D
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
import numpy as np
from numpy import zeros
from numpy import asarray

# %%
def prepare_data(train_docs, test_docs, mode):
    tokenizer=Tokenizer()
    tokenizer.fit_on_texts(train_docs)
    Xtrain=tokenizer.texts_to_matrix(train_docs, mode=mode)
    Xtest =tokenizer.texts_to_matrix(test_docs, mode=mode)
    return Xtrain, Xtest

def load_doc(filename):
    file=open(filename,'r')
    text=file.read()
    file.close()
    return text

def clean_doc(doc, vocab):
    tokens=doc.split()
    re_punc= re.compile('[%s]' % re.escape(string.punctuation))
    tokens=[re_punc.sub('', w) for w in tokens]
    tokens=[word for word in tokens if word.isalpha()]
    stop_words=set(stopwords.words('english'))
    tokens=[w for w in tokens if not w in stop_words]
    tokens=[word for word in tokens if len(word)> 1]
    return tokens

def doc_to_line(filename, vocab):
    doc= load_doc(filename)
    tokens=clean_doc(doc, vocab)
    tokens=[w for w in tokens if w in vocab]
    return ' '.join(tokens) 


def process_docs(directory,vocab, isTrain):
    lines=[]
    for filename in listdir(directory):
        if not filename.endswith(".txt"):
            next
        if isTrain and filename.startswith('cv9'):
            continue
        if not isTrain and not filename.startswith('cv9'):
            continue
        path=directory+"/"+filename
        line=doc_to_line(path, vocab)
        lines.append(line)
    return lines

def add_doc_to_vocab(filename,vocab):
    doc=load_doc(filename)
    tokens=clean_doc(doc)
    vocab.update(tokens)

def load_clean_dataset(vocab, isTrain):
    neg=process_docs('dataset/movie_review/neg', vocab, isTrain)
    pos=process_docs('dataset/movie_review/pos', vocab, isTrain)
    docs=neg+pos
    labels= [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
    return docs, labels

def create_tokenizer(lines):
    tokenizer=Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
def get_embeddings_dict():
    embeddings_index= dict()
    f=open('./embeddings/glove.6B.100d.txt')
    for line in f:
        values=line.split()
        word=values[0]
        coefs= asarray(values[1:], dtype='float32')
        embeddings_index[word]=coefs
    f.close()
    return embeddings_index

def create_weight_matrix( vocab_size, tokenizer):
    embeddings_dict= get_embeddings_dict()
    embedding_matrix=zeros((vocab_size,100))
    for word, i in tokenizer.word_index.items():
        embedding_vector= embeddings_dict.get(word)
        if embedding_vector is not None:
            embedding_matrix[i]= embedding_vector
    return embedding_matrix

# %%
def define_model(vocab_size, max_length, embedding_matrix):
    model=Sequential()
    model.add(Embedding(vocab_size,100, weights=[embedding_matrix], input_length=max_length, trainable= False))
    model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
    model.add(MaxPool1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    # plot_model(model,to_file='model.png',show_shape=True)
    return model

def evaluate_mode(Xtrain, ytrain, Xtest, ytest):
    scores=[]
    n_repeats=30
    n_words=Xtrain.shape[1]
    for i in range(n_repeats):
        model=define_model(n_words)
        model.fit(Xtrain, ytrain, epochs=10, verbose=2)
        loss, acc= model.evaluate(Xtest, ytest, verbose=0)
        scores.append(acc)
    return scores

def encode_docs(tokenizer, max_length, docs):
    encoded= tokenizer.texts_to_sequences(docs)
    padded= pad_sequences(encoded, maxlen=max_length, padding='post')
    return padded

# %%
vocab_filename='vocab.txt'
vocab=load_doc(vocab_filename)
vocab=set(vocab.split())
train_docs, y_train= load_clean_dataset(vocab, True)
tokenizer= create_tokenizer(train_docs)
vocab_size=len(tokenizer.word_index) + 1
print(vocab_size)
y_train=np.asarray(y_train)
# Out:
# 26897

# %%
max_length= max([len(s.split()) for s in train_docs]) 
max_length
embedding_matrix= create_weight_matrix(vocab_size, tokenizer)
Xtrain= encode_docs(tokenizer, max_length, train_docs)
model= define_model(vocab_size, max_length, embedding_matrix)
model.fit(Xtrain, np.asarray(y_train), epochs=100, verbose=2)
model.save('model.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 1319, 100)         2689700
#
#  conv1d_1 (Conv1D)           (None, 1312, 32)          25632
#
#  max_pooling1d_1 (MaxPoolin  (None, 656, 32)           0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 20992)             0
#
#  dense_2 (Dense)             (None, 10)                209930
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2925273 (11.16 MB)
# Trainable params: 235573 (920.21 KB)
# Non-trainable params: 2689700 (10.26 MB)
# _________________________________________________________________
# Epoch 1/100
# 57/57 - 2s - loss: 0.7038 - accuracy: 0.4928 - 2s/epoch - 33ms/step
# Epoch 2/100
# 57/57 - 1s - loss: 0.6612 - accuracy: 0.6228 - 1s/epoch - 23ms/step
# Epoch 3/100
# 57/57 - 1s - loss: 0.5862 - accuracy: 0.7139 - 1s/epoch - 25ms/step
# Epoch 4/100
# 57/57 - 1s - loss: 0.4080 - accuracy: 0.8100 - 1s/epoch - 25ms/step
# Epoch 5/100
# 57/57 - 1s - loss: 0.2032 - accuracy: 0.9411 - 1s/epoch - 25ms/step
# Epoch 6/100
# 57/57 - 1s - loss: 0.0814 - accuracy: 0.9906 - 1s/epoch - 26ms/step
# Epoch 7/100
# 57/57 - 1s - loss: 0.0510 - accuracy: 0.9956 - 1s/epoch - 24ms/step
# Epoch 8/100
# 57/57 - 1s - loss: 0.0176 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 9/100
# 57/57 - 1s - loss: 0.0104 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 10/100
# 57/57 - 1s - loss: 0.0069 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 11/100
# 57/57 - 1s - loss: 0.0051 - accuracy: 1.0000 - 1s/epoch - 19ms/step
# Epoch 12/100
# 57/57 - 1s - loss: 0.0040 - accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 13/100
# 57/57 - 1s - loss: 0.0032 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 14/100
# 57/57 - 1s - loss: 0.0026 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 15/100
# 57/57 - 1s - loss: 0.0021 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 16/100
# 57/57 - 1s - loss: 0.0018 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 17/100
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 18/100
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 19/100
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 20/100
# 57/57 - 1s - loss: 9.8055e-04 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 21/100
# 57/57 - 1s - loss: 8.6953e-04 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 22/100
# 57/57 - 1s - loss: 7.5948e-04 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 23/100
# 57/57 - 1s - loss: 6.7250e-04 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 24/100
# 57/57 - 1s - loss: 6.0329e-04 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 25/100
# 57/57 - 1s - loss: 5.4641e-04 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 26/100
# 57/57 - 2s - loss: 4.9316e-04 - accuracy: 1.0000 - 2s/epoch - 27ms/step
# Epoch 27/100
# 57/57 - 1s - loss: 4.5189e-04 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 28/100
# 57/57 - 1s - loss: 4.1383e-04 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 29/100
# 57/57 - 1s - loss: 3.7794e-04 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 30/100
# 57/57 - 1s - loss: 3.5109e-04 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 31/100
# 57/57 - 1s - loss: 3.1894e-04 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 32/100
# 57/57 - 1s - loss: 2.9505e-04 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 33/100
# 57/57 - 1s - loss: 2.7720e-04 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 34/100
# 57/57 - 1s - loss: 2.5599e-04 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 35/100
# 57/57 - 1s - loss: 2.3859e-04 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 36/100
# 57/57 - 1s - loss: 2.2236e-04 - accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 37/100
# 57/57 - 1s - loss: 2.0806e-04 - accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 38/100
# 57/57 - 1s - loss: 1.9326e-04 - accuracy: 1.0000 - 1s/epoch - 19ms/step
# Epoch 39/100
# 57/57 - 1s - loss: 1.8177e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 40/100
# 57/57 - 1s - loss: 1.7076e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 41/100
# 57/57 - 1s - loss: 1.5952e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 42/100
# 57/57 - 1s - loss: 1.5073e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 43/100
# 57/57 - 1s - loss: 1.4150e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 44/100
# 57/57 - 1s - loss: 1.3396e-04 - accuracy: 1.0000 - 971ms/epoch - 17ms/step
# Epoch 45/100
# 57/57 - 1s - loss: 1.2724e-04 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 46/100
# 57/57 - 1s - loss: 1.1963e-04 - accuracy: 1.0000 - 1s/epoch - 19ms/step
# Epoch 47/100
# 57/57 - 1s - loss: 1.1355e-04 - accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 48/100
# 57/57 - 1s - loss: 1.0662e-04 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 49/100
# 57/57 - 1s - loss: 1.0226e-04 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 50/100
# 57/57 - 1s - loss: 9.5976e-05 - accuracy: 1.0000 - 1s/epoch - 19ms/step
# Epoch 51/100
# 57/57 - 1s - loss: 9.2487e-05 - accuracy: 1.0000 - 1s/epoch - 20ms/step
# Epoch 52/100
# 57/57 - 1s - loss: 8.6698e-05 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 53/100
# 57/57 - 1s - loss: 8.1959e-05 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 54/100
# 57/57 - 1s - loss: 7.8022e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 55/100
# 57/57 - 1s - loss: 7.4064e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 56/100
# 57/57 - 1s - loss: 7.0815e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 57/100
# 57/57 - 1s - loss: 6.7008e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 58/100
# 57/57 - 2s - loss: 6.4398e-05 - accuracy: 1.0000 - 2s/epoch - 26ms/step
# Epoch 59/100
# 57/57 - 1s - loss: 6.1118e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 60/100
# 57/57 - 1s - loss: 5.8516e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 61/100
# 57/57 - 1s - loss: 5.5941e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 62/100
# 57/57 - 1s - loss: 5.3311e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 63/100
# 57/57 - 1s - loss: 5.0968e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 64/100
# 57/57 - 1s - loss: 4.8701e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 65/100
# 57/57 - 1s - loss: 4.6507e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 66/100
# 57/57 - 1s - loss: 4.4673e-05 - accuracy: 1.0000 - 1s/epoch - 23ms/step
# Epoch 67/100
# 57/57 - 1s - loss: 4.2539e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 68/100
# 57/57 - 1s - loss: 4.0684e-05 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 69/100
# 57/57 - 1s - loss: 3.9001e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 70/100
# 57/57 - 1s - loss: 3.7497e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 71/100
# 57/57 - 1s - loss: 3.6021e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 72/100
# 57/57 - 1s - loss: 3.4381e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 73/100
# 57/57 - 1s - loss: 3.3069e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 74/100
# 57/57 - 1s - loss: 3.1860e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 75/100
# 57/57 - 1s - loss: 3.0376e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 76/100
# 57/57 - 1s - loss: 2.9272e-05 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 77/100
# 57/57 - 1s - loss: 2.8023e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 78/100
# 57/57 - 1s - loss: 2.7047e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 79/100
# 57/57 - 1s - loss: 2.5862e-05 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 80/100
# 57/57 - 1s - loss: 2.5199e-05 - accuracy: 1.0000 - 957ms/epoch - 17ms/step
# Epoch 81/100
# 57/57 - 1s - loss: 2.3961e-05 - accuracy: 1.0000 - 940ms/epoch - 16ms/step
# Epoch 82/100
# 57/57 - 1s - loss: 2.2948e-05 - accuracy: 1.0000 - 934ms/epoch - 16ms/step
# Epoch 83/100
# 57/57 - 1s - loss: 2.2135e-05 - accuracy: 1.0000 - 964ms/epoch - 17ms/step
# Epoch 84/100
# 57/57 - 1s - loss: 2.1265e-05 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 85/100
# 57/57 - 1s - loss: 2.0556e-05 - accuracy: 1.0000 - 1s/epoch - 18ms/step
# Epoch 86/100
# 57/57 - 1s - loss: 1.9687e-05 - accuracy: 1.0000 - 1s/epoch - 19ms/step
# Epoch 87/100
# 57/57 - 1s - loss: 1.8887e-05 - accuracy: 1.0000 - 1s/epoch - 22ms/step
# Epoch 88/100
# 57/57 - 1s - loss: 1.8142e-05 - accuracy: 1.0000 - 1s/epoch - 21ms/step
# Epoch 89/100
# 57/57 - 1s - loss: 1.7566e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 90/100
# 57/57 - 1s - loss: 1.6850e-05 - accuracy: 1.0000 - 1s/epoch - 26ms/step
# Epoch 91/100
# 57/57 - 1s - loss: 1.6228e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 92/100
# 57/57 - 1s - loss: 1.5664e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 93/100
# 57/57 - 1s - loss: 1.5027e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 94/100
# 57/57 - 2s - loss: 1.4530e-05 - accuracy: 1.0000 - 2s/epoch - 26ms/step
# Epoch 95/100
# 57/57 - 1s - loss: 1.4006e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 96/100
# 57/57 - 1s - loss: 1.3490e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 97/100
# 57/57 - 1s - loss: 1.2986e-05 - accuracy: 1.0000 - 1s/epoch - 25ms/step
# Epoch 98/100
# 57/57 - 1s - loss: 1.2480e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 99/100
# 57/57 - 1s - loss: 1.2036e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step
# Epoch 100/100
# 57/57 - 1s - loss: 1.1620e-05 - accuracy: 1.0000 - 1s/epoch - 24ms/step

# %% [markdown]
# # Evaluation

# %%
train_docs, y_train= load_clean_dataset(vocab, True)
test_docs, y_test= load_clean_dataset(vocab, False)
tokenizer=create_tokenizer(train_docs)
vocab_size=len(tokenizer.word_index) +1 
max_length= max([len(s.split()) for s in train_docs]) 
Xtrain= encode_docs(tokenizer, max_length, train_docs)
Xtest= encode_docs(tokenizer, max_length, test_docs)
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)

# %%
model=load_model('model.h5')
_, acc= model.evaluate(Xtrain, y_train, verbose=0)
print(f"Train accuracy {acc}")
_, acc= model.evaluate(Xtest, y_test, verbose=0)
print(f"Test accuracy {acc}")
# Out:
# Train accuracy 1.0
# Test accuracy 0.7950000166893005

# %%
def predict_sentiment(review, vocab, tokenizer, max_length, model):
    line= clean_doc(review, vocab)
    padded= encode_docs(tokenizer, max_length, [line])
    yhat=model.predict(padded, verbose=0)
    percent_pos= yhat[0,0]
    if round(percent_pos)==0:
        return (1- percent_pos), "NEGATIVE"
    return percent_pos, "POSITIVE"

def clean_doc(doc, vocab):
    tokens=doc.split()
    re_punc= re.compile('[%s]' % re.escape(string.punctuation))
    tokens=[re_punc.sub('', w) for w in tokens]
    tokens=[word for word in tokens if word in vocab]
    tokens= ' '.join(tokens)
    return tokens

# %%
text= "Really bad movie"
predict_sentiment(text, vocab, tokenizer, max_length, model)
# Out:
# (0.989143367856741, 'NEGATIVE')
