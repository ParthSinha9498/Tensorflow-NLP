# %%
import string
from os import listdir
import re
from collections import Counter
from nltk.corpus import stopwords

# %% [markdown]
# ## Create Vocabulary

# %%
def load_doc(filename):
    file=open(filename,'r')
    text=file.read()
    file.close()
    return text

def clean_doc(doc):
    tokens=doc.split()
    re_punc= re.compile('[%s]' % re.escape(string.punctuation))
    tokens=[re_punc.sub('', w) for w in tokens]
    tokens=[word for word in tokens if word.isalpha()]
    stop_words=set(stopwords.words('english'))
    tokens=[w for w in tokens if not w in stop_words]
    tokens=[word for word in tokens if len(word)> 1]
    return tokens

def add_doc_to_vocab(filename,vocab):
    doc=load_doc(filename)
    tokens=clean_doc(doc)
    vocab.update(tokens)

def process_docs(directory,vocab):
    for filename in listdir(directory):
        if not filename.endswith(".txt"):
            next
        path=directory+"/"+filename
        add_doc_to_vocab(path,vocab)

def save_list(lines, filename):
    data= '\n'.join(lines)
    file=open(filename,'w')
    file.write(data)
    file.close()

# %%
vocab=Counter()
process_docs('dataset/movie_review/neg', vocab)
print(len(vocab))
process_docs('dataset/movie_review/pos', vocab)
print(len(vocab))
min_occurance=2
tokens= [ k for k,c in vocab.items() if c >= min_occurance]
print(len(tokens))

save_list(tokens,'vocab.txt')
# Out:
# 32010
# 46557
# 27139

# %% [markdown]
# ## Use vocabulary to prepare dataset

# %%
def doc_to_line(filename, vocab):
    doc= load_doc(filename)
    tokens=clean_doc(doc)
    tokens=[w for w in tokens if w in vocab]
    return ' '.join(tokens) 

def process_docs(directory,vocab):
    lines=[]
    for filename in listdir(directory):
        if not filename.endswith(".txt"):
            next
        path=directory+"/"+filename
        line=doc_to_line(path, vocab)
        lines.append(line)
    return lines

# %%
vocab_filename='vocab.txt'
vocab=load_doc(vocab_filename)
vocab=vocab.split()
vocab=set(vocab)
negative_lines=process_docs('dataset/movie_review/neg', vocab)
save_list(negative_lines, 'negative.txt')
positive_lines=process_docs('dataset/movie_review/pos', vocab)
save_list(positive_lines, 'positive.txt')

# %% [markdown]
# ## ML part :))

# %%
from keras.preprocessing.text import Tokenizer

def load_clean_dataset(vocab, isTrain):
    neg=process_docs('dataset/movie_review/neg', vocab, isTrain)
    pos=process_docs('dataset/movie_review/pos', vocab, isTrain)
    docs=neg+pos
    labels= [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
    return docs, labels

def process_docs(directory,vocab, isTrain):
    lines=[]
    for filename in listdir(directory):
        if not filename.endswith(".txt"):
            next
        if isTrain and filename.startswith('cv9'):
            continue
        if not isTrain and not filename.startswith('cv9'):
            continue
        path=directory+"/"+filename
        line=doc_to_line(path, vocab)
        lines.append(line)
    return lines

def create_tokenizer(lines):
    tokenizer=Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer
# Out:
# WARNING:tensorflow:From c:\Users\Parth\anaconda3\envs\tf-nlp\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_docs, ytrain=load_clean_dataset(vocab, True)
test_docs, ytest=load_clean_dataset(vocab, False)
tokenizer=create_tokenizer(train_docs)
Xtrain=tokenizer.texts_to_matrix(train_docs, mode='freq')
Xtest =tokenizer.texts_to_matrix(test_docs, mode='freq')

# %%
# from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense

n_words=Xtest.shape[1]

def define_model(n_words):
    model=Sequential()
    model.add(Dense(50, input_shape=(n_words,), activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    # plot_model(model,to_file='model.png',show_shape=True)
    return model

import numpy as np
y_train = np.array(ytrain)
y_test = np.array(ytest)

# %%
model=define_model(n_words)
model.fit(Xtrain, y_train, epochs=10, verbose=2)
loss, acc= model.evaluate(Xtest, y_test, verbose=0)
print(f"Test accuracy {acc * 100}")
# Out:
# WARNING:tensorflow:From c:\Users\Parth\anaconda3\envs\tf-nlp\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Parth\anaconda3\envs\tf-nlp\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                1344900
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Parth\anaconda3\envs\tf-nlp\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Parth\anaconda3\envs\tf-nlp\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 57/57 - 1s - loss: 0.6919 - accuracy: 0.5994 - 1s/epoch - 24ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6833 - accuracy: 0.7267 - 618ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6655 - accuracy: 0.8539 - 636ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6372 - accuracy: 0.8994 - 610ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.5997 - accuracy: 0.9283 - 620ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5577 - accuracy: 0.9333 - 619ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5124 - accuracy: 0.9478 - 623ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4653 - accuracy: 0.9528 - 625ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4213 - accuracy: 0.9572 - 644ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3785 - accuracy: 0.9667 - 590ms/epoch - 10ms/step
# Test accuracy 87.5

# %% [markdown]
# ## Compare scoring methods

# %%
def prepare_data(train_docs, test_docs, mode):
    tokenizer=Tokenizer()
    tokenizer.fit_on_texts(train_docs)
    Xtrain=tokenizer.texts_to_matrix(train_docs, mode=mode)
    Xtest =tokenizer.texts_to_matrix(test_docs, mode=mode)
    return Xtrain, Xtest

def evaluate_mode(Xtrain, ytrain, Xtest, ytest):
    scores=[]
    n_repeats=30
    n_words=Xtrain.shape[1]
    for i in range(n_repeats):
        model=define_model(n_words)
        model.fit(Xtrain, y_train, epochs=10, verbose=2)
        loss, acc= model.evaluate(Xtest, y_test, verbose=0)
        scores.append(acc)
    return scores

# %%
from pandas import DataFrame
modes=['binary','count','tfidf', 'freq']
results=DataFrame()
for mode in modes:
    Xtrain, Xtest= prepare_data(train_docs, test_docs, mode)
    results[mode]=evaluate_mode(Xtrain,y_train, Xtest, y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 50)                1344900
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4699 - accuracy: 0.7894 - 1s/epoch - 21ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0645 - accuracy: 0.9911 - 640ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0151 - accuracy: 1.0000 - 654ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0073 - accuracy: 1.0000 - 699ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0042 - accuracy: 1.0000 - 667ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0024 - accuracy: 1.0000 - 625ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 668ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 669ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.9167e-04 - accuracy: 1.0000 - 637ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.0900e-04 - accuracy: 1.0000 - 618ms/epoch - 11ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 50)                1344900
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4814 - accuracy: 0.7678 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0609 - accuracy: 0.9956 - 618ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0159 - accuracy: 1.0000 - 621ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0077 - accuracy: 1.0000 - 622ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0044 - accuracy: 1.0000 - 611ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0024 - accuracy: 1.0000 - 622ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0016 - accuracy: 1.0000 - 613ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 629ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 8.1796e-04 - accuracy: 1.0000 - 641ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.3428e-04 - accuracy: 1.0000 - 639ms/epoch - 11ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 50)                1344900
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4712 - accuracy: 0.7739 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0576 - accuracy: 0.9956 - 686ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0155 - accuracy: 1.0000 - 746ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0079 - accuracy: 1.0000 - 728ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0049 - accuracy: 1.0000 - 685ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0034 - accuracy: 1.0000 - 680ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0025 - accuracy: 1.0000 - 753ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0019 - accuracy: 1.0000 - 720ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 759ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 771ms/epoch - 14ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 50)                1344900
#
#  dense_9 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4791 - accuracy: 0.7778 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0619 - accuracy: 0.9944 - 672ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0160 - accuracy: 1.0000 - 726ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0068 - accuracy: 1.0000 - 715ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0035 - accuracy: 1.0000 - 717ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0020 - accuracy: 1.0000 - 765ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 763ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 9.7060e-04 - accuracy: 1.0000 - 704ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.2678e-04 - accuracy: 1.0000 - 775ms/epoch - 14ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.6594e-04 - accuracy: 1.0000 - 764ms/epoch - 13ms/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 50)                1344900
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4926 - accuracy: 0.7689 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0688 - accuracy: 0.9956 - 698ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0165 - accuracy: 1.0000 - 791ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0073 - accuracy: 1.0000 - 780ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0039 - accuracy: 1.0000 - 699ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0024 - accuracy: 1.0000 - 780ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 734ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 669ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.2480e-04 - accuracy: 1.0000 - 772ms/epoch - 14ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.3512e-04 - accuracy: 1.0000 - 684ms/epoch - 12ms/step
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 50)                1344900
#
#  dense_13 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4877 - accuracy: 0.7783 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0705 - accuracy: 0.9961 - 677ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0210 - accuracy: 1.0000 - 792ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0087 - accuracy: 1.0000 - 745ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0042 - accuracy: 1.0000 - 655ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 783ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 746ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 8.8768e-04 - accuracy: 1.0000 - 698ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 6.5301e-04 - accuracy: 1.0000 - 725ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.0437e-04 - accuracy: 1.0000 - 683ms/epoch - 12ms/step
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 50)                1344900
#
#  dense_15 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4657 - accuracy: 0.7744 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0481 - accuracy: 0.9961 - 678ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0151 - accuracy: 1.0000 - 776ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0074 - accuracy: 1.0000 - 697ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0043 - accuracy: 1.0000 - 716ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0027 - accuracy: 1.0000 - 800ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0019 - accuracy: 1.0000 - 679ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 722ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 673ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 8.4534e-04 - accuracy: 1.0000 - 752ms/epoch - 13ms/step
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 50)                1344900
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4769 - accuracy: 0.7722 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0643 - accuracy: 0.9917 - 655ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0173 - accuracy: 1.0000 - 707ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0080 - accuracy: 1.0000 - 699ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0044 - accuracy: 1.0000 - 656ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0026 - accuracy: 1.0000 - 698ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0017 - accuracy: 1.0000 - 736ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 631ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 8.6449e-04 - accuracy: 1.0000 - 652ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.6660e-04 - accuracy: 1.0000 - 735ms/epoch - 13ms/step
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 50)                1344900
#
#  dense_19 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4626 - accuracy: 0.7889 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0542 - accuracy: 0.9961 - 639ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0167 - accuracy: 1.0000 - 790ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0077 - accuracy: 1.0000 - 761ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0040 - accuracy: 1.0000 - 716ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 770ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 782ms/epoch - 14ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 8.7287e-04 - accuracy: 1.0000 - 704ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 5.9820e-04 - accuracy: 1.0000 - 774ms/epoch - 14ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 4.3524e-04 - accuracy: 1.0000 - 767ms/epoch - 13ms/step
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 50)                1344900
#
#  dense_21 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4751 - accuracy: 0.7706 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0607 - accuracy: 0.9944 - 675ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0172 - accuracy: 1.0000 - 665ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0069 - accuracy: 1.0000 - 677ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0036 - accuracy: 1.0000 - 668ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 783ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 660ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 722ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.4865e-04 - accuracy: 1.0000 - 647ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.6108e-04 - accuracy: 1.0000 - 643ms/epoch - 11ms/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 50)                1344900
#
#  dense_23 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4865 - accuracy: 0.7706 - 1s/epoch - 22ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0680 - accuracy: 0.9939 - 631ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0168 - accuracy: 1.0000 - 660ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0071 - accuracy: 1.0000 - 674ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0039 - accuracy: 1.0000 - 696ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 698ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 693ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 9.2626e-04 - accuracy: 1.0000 - 673ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 6.2605e-04 - accuracy: 1.0000 - 688ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 4.5273e-04 - accuracy: 1.0000 - 704ms/epoch - 12ms/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 50)                1344900
#
#  dense_25 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4755 - accuracy: 0.7717 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0562 - accuracy: 0.9933 - 615ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 0s - loss: 0.0147 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 4/10
# 57/57 - 0s - loss: 0.0071 - accuracy: 1.0000 - 472ms/epoch - 8ms/step
# Epoch 5/10
# 57/57 - 0s - loss: 0.0044 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 6/10
# 57/57 - 0s - loss: 0.0030 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 7/10
# 57/57 - 0s - loss: 0.0022 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 8/10
# 57/57 - 0s - loss: 0.0017 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 9/10
# 57/57 - 0s - loss: 0.0013 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 10/10
# 57/57 - 0s - loss: 0.0011 - accuracy: 1.0000 - 464ms/epoch - 8ms/step
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 50)                1344900
#
#  dense_27 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4569 - accuracy: 0.7950 - 1s/epoch - 24ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0498 - accuracy: 0.9933 - 659ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0137 - accuracy: 1.0000 - 624ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0061 - accuracy: 1.0000 - 642ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0034 - accuracy: 1.0000 - 633ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0021 - accuracy: 1.0000 - 622ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 643ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 623ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 8.3526e-04 - accuracy: 1.0000 - 625ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.6323e-04 - accuracy: 1.0000 - 609ms/epoch - 11ms/step
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 50)                1344900
#
#  dense_29 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4890 - accuracy: 0.7672 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0703 - accuracy: 0.9883 - 640ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0154 - accuracy: 1.0000 - 629ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0064 - accuracy: 1.0000 - 796ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0033 - accuracy: 1.0000 - 774ms/epoch - 14ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0017 - accuracy: 1.0000 - 684ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 9.4654e-04 - accuracy: 1.0000 - 787ms/epoch - 14ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 6.1353e-04 - accuracy: 1.0000 - 757ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 4.4079e-04 - accuracy: 1.0000 - 654ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 3.3530e-04 - accuracy: 1.0000 - 721ms/epoch - 13ms/step
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 50)                1344900
#
#  dense_31 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4873 - accuracy: 0.7589 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0630 - accuracy: 0.9933 - 744ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0176 - accuracy: 1.0000 - 684ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0076 - accuracy: 1.0000 - 818ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0037 - accuracy: 1.0000 - 705ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 750ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 740ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 740ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.4766e-04 - accuracy: 1.0000 - 827ms/epoch - 15ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.7946e-04 - accuracy: 1.0000 - 765ms/epoch - 13ms/step
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 50)                1344900
#
#  dense_33 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.5107 - accuracy: 0.7628 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0867 - accuracy: 0.9900 - 690ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0201 - accuracy: 1.0000 - 730ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0072 - accuracy: 1.0000 - 703ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0034 - accuracy: 1.0000 - 660ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0020 - accuracy: 1.0000 - 690ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 769ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 8.7017e-04 - accuracy: 1.0000 - 687ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 6.3738e-04 - accuracy: 1.0000 - 767ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 4.8333e-04 - accuracy: 1.0000 - 783ms/epoch - 14ms/step
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_34 (Dense)            (None, 50)                1344900
#
#  dense_35 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4827 - accuracy: 0.7678 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0668 - accuracy: 0.9939 - 730ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0170 - accuracy: 1.0000 - 620ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0076 - accuracy: 1.0000 - 612ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0043 - accuracy: 1.0000 - 637ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0027 - accuracy: 1.0000 - 725ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0018 - accuracy: 1.0000 - 741ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 725ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 9.1134e-04 - accuracy: 1.0000 - 793ms/epoch - 14ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.9798e-04 - accuracy: 1.0000 - 770ms/epoch - 14ms/step
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 50)                1344900
#
#  dense_37 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4640 - accuracy: 0.7889 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0547 - accuracy: 0.9950 - 711ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0144 - accuracy: 1.0000 - 736ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0067 - accuracy: 1.0000 - 757ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0037 - accuracy: 1.0000 - 691ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 715ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 678ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 9.9602e-04 - accuracy: 1.0000 - 672ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.0885e-04 - accuracy: 1.0000 - 728ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.2926e-04 - accuracy: 1.0000 - 680ms/epoch - 12ms/step
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 50)                1344900
#
#  dense_39 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4547 - accuracy: 0.7961 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0532 - accuracy: 0.9944 - 655ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0142 - accuracy: 1.0000 - 747ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0069 - accuracy: 1.0000 - 718ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0041 - accuracy: 1.0000 - 690ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0027 - accuracy: 1.0000 - 763ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0019 - accuracy: 1.0000 - 709ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 657ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 703ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 8.1031e-04 - accuracy: 1.0000 - 746ms/epoch - 13ms/step
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 50)                1344900
#
#  dense_41 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4713 - accuracy: 0.7956 - 976ms/epoch - 17ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0607 - accuracy: 0.9939 - 594ms/epoch - 10ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0170 - accuracy: 1.0000 - 615ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0086 - accuracy: 1.0000 - 626ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0051 - accuracy: 1.0000 - 593ms/epoch - 10ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0033 - accuracy: 1.0000 - 645ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 676ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0016 - accuracy: 1.0000 - 729ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 619ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 9.4430e-04 - accuracy: 1.0000 - 740ms/epoch - 13ms/step
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 50)                1344900
#
#  dense_43 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4684 - accuracy: 0.7850 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0591 - accuracy: 0.9928 - 614ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0162 - accuracy: 1.0000 - 732ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0077 - accuracy: 1.0000 - 693ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0042 - accuracy: 1.0000 - 665ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0026 - accuracy: 1.0000 - 723ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0017 - accuracy: 1.0000 - 709ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 696ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 9.1791e-04 - accuracy: 1.0000 - 650ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 7.0467e-04 - accuracy: 1.0000 - 649ms/epoch - 11ms/step
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 50)                1344900
#
#  dense_45 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4733 - accuracy: 0.7767 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0569 - accuracy: 0.9944 - 609ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0145 - accuracy: 1.0000 - 620ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0061 - accuracy: 1.0000 - 623ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0033 - accuracy: 1.0000 - 540ms/epoch - 9ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0021 - accuracy: 1.0000 - 500ms/epoch - 9ms/step
# Epoch 7/10
# 57/57 - 0s - loss: 0.0014 - accuracy: 1.0000 - 469ms/epoch - 8ms/step
# Epoch 8/10
# 57/57 - 0s - loss: 0.0010 - accuracy: 1.0000 - 468ms/epoch - 8ms/step
# Epoch 9/10
# 57/57 - 0s - loss: 7.5948e-04 - accuracy: 1.0000 - 446ms/epoch - 8ms/step
# Epoch 10/10
# 57/57 - 0s - loss: 5.7372e-04 - accuracy: 1.0000 - 455ms/epoch - 8ms/step
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_46 (Dense)            (None, 50)                1344900
#
#  dense_47 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4821 - accuracy: 0.7739 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0626 - accuracy: 0.9922 - 517ms/epoch - 9ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0156 - accuracy: 1.0000 - 526ms/epoch - 9ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0078 - accuracy: 1.0000 - 522ms/epoch - 9ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0045 - accuracy: 1.0000 - 504ms/epoch - 9ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0027 - accuracy: 1.0000 - 534ms/epoch - 9ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0018 - accuracy: 1.0000 - 550ms/epoch - 10ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 551ms/epoch - 10ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 9.1092e-04 - accuracy: 1.0000 - 557ms/epoch - 10ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.7816e-04 - accuracy: 1.0000 - 571ms/epoch - 10ms/step
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 50)                1344900
#
#  dense_49 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4807 - accuracy: 0.7828 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0675 - accuracy: 0.9944 - 562ms/epoch - 10ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0184 - accuracy: 1.0000 - 562ms/epoch - 10ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0078 - accuracy: 1.0000 - 586ms/epoch - 10ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0040 - accuracy: 1.0000 - 594ms/epoch - 10ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 578ms/epoch - 10ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 588ms/epoch - 10ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 583ms/epoch - 10ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.3136e-04 - accuracy: 1.0000 - 600ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.4877e-04 - accuracy: 1.0000 - 709ms/epoch - 12ms/step
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_50 (Dense)            (None, 50)                1344900
#
#  dense_51 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4675 - accuracy: 0.7783 - 976ms/epoch - 17ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0531 - accuracy: 0.9928 - 631ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0138 - accuracy: 1.0000 - 756ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0066 - accuracy: 1.0000 - 668ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0039 - accuracy: 1.0000 - 772ms/epoch - 14ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0026 - accuracy: 1.0000 - 800ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0019 - accuracy: 1.0000 - 664ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 683ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 667ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 8.9316e-04 - accuracy: 1.0000 - 666ms/epoch - 12ms/step
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 50)                1344900
#
#  dense_53 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4706 - accuracy: 0.7950 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0589 - accuracy: 0.9944 - 643ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0160 - accuracy: 1.0000 - 772ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0072 - accuracy: 1.0000 - 745ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0037 - accuracy: 1.0000 - 725ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 740ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 722ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 691ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.3701e-04 - accuracy: 1.0000 - 732ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 5.5533e-04 - accuracy: 1.0000 - 624ms/epoch - 11ms/step
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 50)                1344900
#
#  dense_55 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4853 - accuracy: 0.7561 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0553 - accuracy: 0.9944 - 652ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0144 - accuracy: 1.0000 - 733ms/epoch - 13ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0064 - accuracy: 1.0000 - 727ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0036 - accuracy: 1.0000 - 721ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0022 - accuracy: 1.0000 - 742ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 651ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 740ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 8.2760e-04 - accuracy: 1.0000 - 717ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.4091e-04 - accuracy: 1.0000 - 709ms/epoch - 12ms/step
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_56 (Dense)            (None, 50)                1344900
#
#  dense_57 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4544 - accuracy: 0.7956 - 1s/epoch - 26ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0472 - accuracy: 0.9956 - 631ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0144 - accuracy: 1.0000 - 658ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0074 - accuracy: 1.0000 - 631ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0047 - accuracy: 1.0000 - 624ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0032 - accuracy: 1.0000 - 671ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 581ms/epoch - 10ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0017 - accuracy: 1.0000 - 678ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 598ms/epoch - 10ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 606ms/epoch - 11ms/step
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_58 (Dense)            (None, 50)                1344900
#
#  dense_59 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4670 - accuracy: 0.7933 - 1s/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0546 - accuracy: 0.9967 - 652ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0175 - accuracy: 1.0000 - 623ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0084 - accuracy: 1.0000 - 713ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0047 - accuracy: 1.0000 - 697ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0029 - accuracy: 1.0000 - 722ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0020 - accuracy: 1.0000 - 729ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0014 - accuracy: 1.0000 - 713ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 9.8878e-04 - accuracy: 1.0000 - 664ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 7.1089e-04 - accuracy: 1.0000 - 699ms/epoch - 12ms/step
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 50)                1344900
#
#  dense_61 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.5032 - accuracy: 0.7456 - 1000ms/epoch - 18ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0737 - accuracy: 0.9906 - 708ms/epoch - 12ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0156 - accuracy: 1.0000 - 672ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0074 - accuracy: 1.0000 - 696ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0044 - accuracy: 1.0000 - 726ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0028 - accuracy: 1.0000 - 664ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0018 - accuracy: 1.0000 - 658ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0012 - accuracy: 1.0000 - 680ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 7.6990e-04 - accuracy: 1.0000 - 707ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 4.9979e-04 - accuracy: 1.0000 - 642ms/epoch - 11ms/step
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_62 (Dense)            (None, 50)                1344900
#
#  dense_63 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4705 - accuracy: 0.7694 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0595 - accuracy: 0.9911 - 654ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0150 - accuracy: 1.0000 - 659ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0069 - accuracy: 1.0000 - 649ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0038 - accuracy: 1.0000 - 674ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0023 - accuracy: 1.0000 - 769ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0015 - accuracy: 1.0000 - 649ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0011 - accuracy: 1.0000 - 666ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 8.2416e-04 - accuracy: 1.0000 - 650ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 6.5073e-04 - accuracy: 1.0000 - 625ms/epoch - 11ms/step
# Model: "sequential_32"
# ...
# Epoch 4/10
# 57/57 - 1s - loss: 0.6393 - accuracy: 0.8756 - 666ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6047 - accuracy: 0.9367 - 724ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5637 - accuracy: 0.9344 - 649ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5195 - accuracy: 0.9500 - 607ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4744 - accuracy: 0.9467 - 650ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4309 - accuracy: 0.9611 - 548ms/epoch - 10ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3904 - accuracy: 0.9611 - 668ms/epoch - 12ms/step
# Model: "sequential_111"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_222 (Dense)           (None, 50)                1344900
#
#  dense_223 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6917 - accuracy: 0.5989 - 1s/epoch - 21ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6833 - accuracy: 0.8150 - 647ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6675 - accuracy: 0.7583 - 658ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6428 - accuracy: 0.9000 - 641ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6082 - accuracy: 0.9328 - 670ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 0s - loss: 0.5678 - accuracy: 0.9406 - 476ms/epoch - 8ms/step
# Epoch 7/10
# 57/57 - 0s - loss: 0.5236 - accuracy: 0.9467 - 490ms/epoch - 9ms/step
# Epoch 8/10
# 57/57 - 0s - loss: 0.4777 - accuracy: 0.9506 - 490ms/epoch - 9ms/step
# Epoch 9/10
# 57/57 - 0s - loss: 0.4329 - accuracy: 0.9572 - 434ms/epoch - 8ms/step
# Epoch 10/10
# 57/57 - 0s - loss: 0.3923 - accuracy: 0.9617 - 432ms/epoch - 8ms/step
# Model: "sequential_112"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_224 (Dense)           (None, 50)                1344900
#
#  dense_225 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6913 - accuracy: 0.5722 - 1s/epoch - 20ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6799 - accuracy: 0.6422 - 600ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6574 - accuracy: 0.9061 - 612ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6257 - accuracy: 0.8761 - 606ms/epoch - 11ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.5852 - accuracy: 0.9233 - 622ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5408 - accuracy: 0.9483 - 619ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.4938 - accuracy: 0.9528 - 659ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4456 - accuracy: 0.9572 - 614ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4010 - accuracy: 0.9622 - 598ms/epoch - 10ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3588 - accuracy: 0.9672 - 616ms/epoch - 11ms/step
# Model: "sequential_113"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_226 (Dense)           (None, 50)                1344900
#
#  dense_227 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6926 - accuracy: 0.5578 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6886 - accuracy: 0.8878 - 571ms/epoch - 10ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6802 - accuracy: 0.7728 - 660ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6654 - accuracy: 0.8828 - 703ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6450 - accuracy: 0.9133 - 770ms/epoch - 14ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.6187 - accuracy: 0.9267 - 637ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5897 - accuracy: 0.9400 - 687ms/epoch - 12ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.5577 - accuracy: 0.9461 - 812ms/epoch - 14ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.5254 - accuracy: 0.9472 - 739ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.4918 - accuracy: 0.9500 - 814ms/epoch - 14ms/step
# Model: "sequential_114"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_228 (Dense)           (None, 50)                1344900
#
#  dense_229 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 2s - loss: 0.6919 - accuracy: 0.6267 - 2s/epoch - 36ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6847 - accuracy: 0.8067 - 727ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6708 - accuracy: 0.8817 - 782ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6483 - accuracy: 0.9078 - 714ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6178 - accuracy: 0.9217 - 678ms/epoch - 12ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5815 - accuracy: 0.9378 - 662ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5418 - accuracy: 0.9450 - 719ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.5017 - accuracy: 0.9494 - 717ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4600 - accuracy: 0.9533 - 699ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.4199 - accuracy: 0.9583 - 672ms/epoch - 12ms/step
# Model: "sequential_115"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_230 (Dense)           (None, 50)                1344900
#
#  dense_231 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6916 - accuracy: 0.5244 - 1s/epoch - 20ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6820 - accuracy: 0.7506 - 715ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6653 - accuracy: 0.8672 - 775ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6402 - accuracy: 0.8406 - 786ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6060 - accuracy: 0.9344 - 744ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5664 - accuracy: 0.9394 - 848ms/epoch - 15ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5242 - accuracy: 0.9483 - 782ms/epoch - 14ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4807 - accuracy: 0.9544 - 843ms/epoch - 15ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4387 - accuracy: 0.9578 - 750ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3973 - accuracy: 0.9689 - 807ms/epoch - 14ms/step
# Model: "sequential_116"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_232 (Dense)           (None, 50)                1344900
#
#  dense_233 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6918 - accuracy: 0.5978 - 1s/epoch - 21ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6828 - accuracy: 0.7844 - 803ms/epoch - 14ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6657 - accuracy: 0.8717 - 680ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6392 - accuracy: 0.8472 - 813ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6043 - accuracy: 0.9322 - 774ms/epoch - 14ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5629 - accuracy: 0.9383 - 758ms/epoch - 13ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5181 - accuracy: 0.9506 - 840ms/epoch - 15ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4732 - accuracy: 0.9578 - 725ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4298 - accuracy: 0.9572 - 828ms/epoch - 15ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3885 - accuracy: 0.9689 - 837ms/epoch - 15ms/step
# Model: "sequential_117"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_234 (Dense)           (None, 50)                1344900
#
#  dense_235 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6917 - accuracy: 0.6156 - 1s/epoch - 21ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6844 - accuracy: 0.6083 - 778ms/epoch - 14ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6713 - accuracy: 0.7206 - 838ms/epoch - 15ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6516 - accuracy: 0.7322 - 795ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.6273 - accuracy: 0.8350 - 727ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5961 - accuracy: 0.8867 - 805ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5613 - accuracy: 0.9339 - 770ms/epoch - 14ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.5242 - accuracy: 0.9461 - 826ms/epoch - 14ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4865 - accuracy: 0.9567 - 718ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.4492 - accuracy: 0.9644 - 692ms/epoch - 12ms/step
# Model: "sequential_118"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_236 (Dense)           (None, 50)                1344900
#
#  dense_237 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6915 - accuracy: 0.6600 - 1s/epoch - 19ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6822 - accuracy: 0.6817 - 771ms/epoch - 14ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6639 - accuracy: 0.8022 - 798ms/epoch - 14ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6355 - accuracy: 0.9183 - 766ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.5990 - accuracy: 0.9317 - 794ms/epoch - 14ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5575 - accuracy: 0.9344 - 772ms/epoch - 14ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5133 - accuracy: 0.9489 - 759ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4680 - accuracy: 0.9528 - 758ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4242 - accuracy: 0.9594 - 729ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3840 - accuracy: 0.9678 - 775ms/epoch - 14ms/step
# Model: "sequential_119"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_238 (Dense)           (None, 50)                1344900
#
#  dense_239 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6910 - accuracy: 0.6344 - 1s/epoch - 20ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6791 - accuracy: 0.6683 - 722ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6578 - accuracy: 0.7972 - 702ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6264 - accuracy: 0.8917 - 765ms/epoch - 13ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.5858 - accuracy: 0.9311 - 725ms/epoch - 13ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5401 - accuracy: 0.9467 - 709ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.4935 - accuracy: 0.9483 - 736ms/epoch - 13ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4470 - accuracy: 0.9550 - 740ms/epoch - 13ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4027 - accuracy: 0.9611 - 769ms/epoch - 13ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3625 - accuracy: 0.9661 - 795ms/epoch - 14ms/step
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_240 (Dense)           (None, 50)                1344900
#
#  dense_241 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.6914 - accuracy: 0.5928 - 1s/epoch - 20ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.6808 - accuracy: 0.7817 - 737ms/epoch - 13ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.6610 - accuracy: 0.8200 - 665ms/epoch - 12ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.6317 - accuracy: 0.9283 - 812ms/epoch - 14ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.5957 - accuracy: 0.9356 - 643ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.5542 - accuracy: 0.9444 - 668ms/epoch - 12ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.5107 - accuracy: 0.9511 - 773ms/epoch - 14ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.4672 - accuracy: 0.9600 - 695ms/epoch - 12ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.4251 - accuracy: 0.9644 - 685ms/epoch - 12ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 0.3846 - accuracy: 0.9622 - 678ms/epoch - 12ms/step

# %%
print(results.describe())
# Out:
#           binary      count      tfidf      freq
# count  30.000000  30.000000  30.000000  30.00000
# mean    0.922333   0.894833   0.873333   0.86500
# std     0.009714   0.010544   0.011090   0.02205
# min     0.900000   0.865000   0.845000   0.75500
# 25%     0.915000   0.890000   0.866250   0.86500
# 50%     0.925000   0.895000   0.875000   0.87000
# 75%     0.930000   0.900000   0.880000   0.87500
# max     0.940000   0.915000   0.890000   0.88000

# %%
def predict_sentiment(review, vocab, tokenizer, model):
    tokens= clean_doc(review)
    tokens=[w  for w in tokens if w in vocab]
    line=' '.join(tokens)
    encoded=tokenizer.texts_to_matrix([line],mode='binary')
    yhat=model.predict(encoded, verbose=0)
    return yhat
model=define_model(n_words)
Xtrain, Xtest= prepare_data(train_docs, test_docs, 'binary')
model.fit(Xtrain, y_train, epochs=10, verbose=2)
# Out:
# Model: "sequential_122"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_244 (Dense)           (None, 50)                1344900
#
#  dense_245 (Dense)           (None, 1)                 51
#
# =================================================================
# Total params: 1344951 (5.13 MB)
# Trainable params: 1344951 (5.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 57/57 - 1s - loss: 0.4755 - accuracy: 0.7833 - 1s/epoch - 20ms/step
# Epoch 2/10
# 57/57 - 1s - loss: 0.0591 - accuracy: 0.9956 - 619ms/epoch - 11ms/step
# Epoch 3/10
# 57/57 - 1s - loss: 0.0154 - accuracy: 1.0000 - 634ms/epoch - 11ms/step
# Epoch 4/10
# 57/57 - 1s - loss: 0.0073 - accuracy: 1.0000 - 657ms/epoch - 12ms/step
# Epoch 5/10
# 57/57 - 1s - loss: 0.0040 - accuracy: 1.0000 - 652ms/epoch - 11ms/step
# Epoch 6/10
# 57/57 - 1s - loss: 0.0026 - accuracy: 1.0000 - 646ms/epoch - 11ms/step
# Epoch 7/10
# 57/57 - 1s - loss: 0.0018 - accuracy: 1.0000 - 633ms/epoch - 11ms/step
# Epoch 8/10
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 634ms/epoch - 11ms/step
# Epoch 9/10
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 636ms/epoch - 11ms/step
# Epoch 10/10
# 57/57 - 1s - loss: 7.9723e-04 - accuracy: 1.0000 - 618ms/epoch - 11ms/step

# %%
text=' Best movie ever! Pretty good movie'
predict_sentiment(text, vocab, tokenizer, model)
# Out:
# array([[0.5110105]], dtype=float32)
